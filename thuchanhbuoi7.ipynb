# %%
#W7A1
def binary_search(arr: list[int], left: int, right: int, target: int) -> int:
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1
lst = list(map(int,input().split()))
k = int(input())
l = 0
r = len(lst) - 1
print(binary_search(lst, l, r, k))
# Out:
# 2

# %%
#W7A2
def count_occurrences(arr: list[int], target: int) -> int:
    count = 0
    for num in arr:
        if num == target:
            count += 1
    return count
lst = list(map(int,input().split()))
k = int(input())
print(count_occurrences(lst, k))
# Out:
# 0

# %%
#W7A3
def bubble_sort(arr: list[int]) -> list[int]:
    n = len(arr)
    swap = False
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swap = True
        if not swap:
            return arr
    return arr
def selection_sort(arr: list[int]) -> list[int]:
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
lst = list(map(int,input().split()))
print(bubble_sort(lst))
# Out:
# [1, 2, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
#W7A4
a = list(map(int,input().split()))
freq = {}
for num in a:
    if num in freq:
        freq[num] += 1
    else:
        freq[num] = 1
max_freq = max(freq.values())
for num in a:
    if freq[num] == max_freq:
        print(f"{num} xuat hien nhieu nhat, som nhat, {max_freq} lan")
        break
# Out:
# 1 xuat hien nhieu nhat, som nhat, 4 lan

# %%
#W7A5
a = list(map(int, input().split()))
k = int(input())
freq = {}
cnt = 0
for x in a:
    if k - x in freq:
        cnt += freq[k - x]
    if x in freq:
        freq[x] += 1
    else:
        freq[x] = 1
print(cnt)
# Out:
# 14

# %%
#W7A6
a = eval(input())
res = []
for num in a:
    res.extend(num)
print(res)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#W7A7
def lengthOfLIS(nums):
    if not nums:
        return 0

    tails = []

    def lower_bound(arr, x):
        left, right = 0, len(arr) - 1
        pos = len(arr)
        while left <= right:
            mid = (left + right) // 2
            if arr[mid] >= x:
                pos = mid
                right = mid - 1
            else:
                left = mid + 1
        return pos

    for x in nums:
        pos = lower_bound(tails, x)
        if pos == len(tails):
            tails.append(x)
        else:
            tails[pos] = x

    return len(tails)
a = eval(input())
print(lengthOfLIS(a))
# Out:
# 4

# %%
#W7A8
a = eval(input())
b = eval(input())
res = []
for x in b:
    min = float('inf')
    for y in a:
        if x >= y[0] and x <= y[1] and y[1] - y[0] + 1 <= min:
            min = y[1] - y[0] + 1
    if min == float('inf'):
        res.append(-1)
    else:
        res.append(min)
print(res)
# Out:
# [3, 3, 1, 4]

# %%
#W7A9
a = eval(input())
res = []
for i in range(len(a)-1):
    cnt = 0
    for j in range(i+1, len(a)):
        if a[j] < a[i]:
            cnt += 1
    res.append(cnt)
res.append(0)
print(res)
# Out:
# [3, 1, 1, 1, 0]

# %%
#W7A10
a = eval(input())
m = int(input())
res = []
for i in range(len(a)-1):
    for j in range(i+1, len(a)):
        res.append(sum(a[i:j])%m)
print(max(res))
# Out:
# 6

# %%
#W7A11
a = input()
b = input()
res = a.count(b)
print(res)

# %%
#W7A12
a1 = input()
a2 = input()
a3 = input()
a4 = input()
lst =[["A",a1],["B",a2],["C",a3],["D",a4]]
res = sorted(lst, key=lambda x: x[1])
for item in res:
    print(item[0], end=' ')
# Out:
# C D A B

# %%
#W7A13
a = list(map(int, input().split()))
freq = {}
res = []
for num in a:
    if num in freq:
        freq[num] += 1
    else:
        freq[num] = 1
for num in a:
    if num - 1 in freq and num + 1 in freq:
        res.append(max(freq[num - 1], freq[num + 1])+ freq[num])
    elif num - 1 in freq:
        res.append(freq[num - 1] + freq[num])
    elif num + 1 in freq:
        res.append(freq[num + 1] + freq[num])

# %%
#W7A14
n = int(input())
a = list(map(int,input().split()))
if 7 not in a:
    print("Not found")
else:
    for i in range(len(a)):
        if a[i] == 7:
            print(i,end = " ")
# Out:
# Not found

# %%
#W7A15
n = int(input())
a = []
for _ in range(n):
    name = input()
    a.append(name)
for i in range(len(a)):
    if a[i] == "Nemo":
        if i == n - 1:
            print(a[i-1],"and",a[-1])
        elif i == 0: 
            print(a[n-1],"and",a[i+1])
        else:
            print(a[i-1],"and",a[i+1])
        break
# Out:
# bert and aurora
